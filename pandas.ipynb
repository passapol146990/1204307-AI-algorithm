# %% [markdown]
# ### 66011212067 พัสพล สุทาธรรม

# %%
pip install pandas openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# ...

# %%
import pandas as pd
data = [['66011201','Rapee',25,22],
        ['66011202','Sppkjai',23,24],
        ['66011203','Rakdee',19,25],
        ['66011204','Chan',21,19],
        ['66011205','Krit',20,18]]
column_name = ['ID', 'Name', 'Midterm', 'Final']
df = pd.DataFrame(data,columns=column_name)
print(df)
# Out:
#          ID     Name  Midterm  Final
# 0  66011201    Rapee       25     22
# 1  66011202  Sppkjai       23     24
# 2  66011203   Rakdee       19     25
# 3  66011204     Chan       21     19
# 4  66011205     Krit       20     18

# %%
df2 = pd.DataFrame(data)
df2
# Out:
#           0        1   2   3
# 0  66011201    Rapee  25  22
# 1  66011202  Sppkjai  23  24
# 2  66011203   Rakdee  19  25
# 3  66011204     Chan  21  19
# 4  66011205     Krit  20  18

# %%
df.head(2)
# Out:
#          ID     Name  Midterm  Final
# 0  66011201    Rapee       25     22
# 1  66011202  Sppkjai       23     24

# %%
df2.head()
# Out:
#           0        1   2   3
# 0  66011201    Rapee  25  22
# 1  66011202  Sppkjai  23  24
# 2  66011203   Rakdee  19  25
# 3  66011204     Chan  21  19
# 4  66011205     Krit  20  18

# %% [markdown]
# ## บันทึกข้อมูลลงไฟล์

# %%
file_csv1 = 'Data/student1.csv'
file_csv2 = 'Data/student2.csv'
file_excel1 = 'Data/Student.xlsx'

df.to_csv(file_csv1)
df.to_csv(file_csv2, index=False)
df.to_excel(file_excel1, index=False)

# %% [markdown]
# ## อ่านข้อมูลจากไฟล์

# %%
df_read_csv = pd.read_csv(file_csv2)
df_read_csv.head(2)
# Out:
#          ID     Name  Midterm  Final
# 0  66011201    Rapee       25     22
# 1  66011202  Sppkjai       23     24

# %%
df_read_excel = pd.read_excel(file_excel1)
df_read_excel
# Out:
#          ID     Name  Midterm  Final
# 0  66011201    Rapee       25     22
# 1  66011202  Sppkjai       23     24
# 2  66011203   Rakdee       19     25
# 3  66011204     Chan       21     19
# 4  66011205     Krit       20     18

# %% [markdown]
# ## ต้องการแค่บาง คอลัม

# %%
col_name = ['ID', 'Name', 'Final']
df2 = pd.read_csv(file_csv2, usecols=col_name)
df2.head()
# Out:
#          ID     Name  Final
# 0  66011201    Rapee     22
# 1  66011202  Sppkjai     24
# 2  66011203   Rakdee     25
# 3  66011204     Chan     19
# 4  66011205     Krit     18

# %% [markdown]
# ## ดึงข้อมูลมาแค่ที่ต้องการ

# %%
df3 = pd.read_csv(file_csv2, usecols=col_name, nrows=4) # ดึงข้อมูล 4 ชุด
df3
# Out:
#          ID     Name  Final
# 0  66011201    Rapee     22
# 1  66011202  Sppkjai     24
# 2  66011203   Rakdee     25
# 3  66011204     Chan     19

# %%
df4 = pd.read_csv(file_csv2, usecols=col_name, skiprows=[1,3])
df4.head()
# Out:
#          ID     Name  Final
# 0  66011202  Sppkjai     24
# 1  66011204     Chan     19
# 2  66011205     Krit     18

# %% [markdown]
# ## ข้อมูลทางสถิติ

# %%
df = pd.read_csv(file_csv2)
df.describe()
# Out:
#                  ID    Midterm     Final
# count  5.000000e+00   5.000000   5.00000
# mean   6.601120e+07  21.600000  21.60000
# std    1.581139e+00   2.408319   3.04959
# min    6.601120e+07  19.000000  18.00000
# 25%    6.601120e+07  20.000000  19.00000
# 50%    6.601120e+07  21.000000  22.00000
# 75%    6.601120e+07  23.000000  24.00000
# max    6.601120e+07  25.000000  25.00000

# %%
print(f"Mean={df.Final.mean()}\nSD={df.Final.std()}")
print(f"Max={df.Final.max()}\nMin={df.Final.min()}")
print(f"Sum={df.Final.sum()}")
# Out:
# Mean=21.6
# SD=3.0495901363953815
# Max=25
# Min=18
# Sum=108

# %%
df.ID[1:4]
# Out:
# 1    66011202
# 2    66011203
# 3    66011204
# Name: ID, dtype: int64

# %%
df[1:4]
# Out:
#          ID     Name  Midterm  Final
# 1  66011202  Sppkjai       23     24
# 2  66011203   Rakdee       19     25
# 3  66011204     Chan       21     19

# %%
df.loc[(df.Midterm<=20)]
# Out:
#          ID    Name  Midterm  Final
# 2  66011203  Rakdee       19     25
# 4  66011205    Krit       20     18

# %%
df.at[1,'Midterm']
df.head(3)
# Out:
#          ID     Name  Midterm  Final
# 0  66011201    Rapee       25     22
# 1  66011202  Sppkjai       23     24
# 2  66011203   Rakdee       19     25

# %%
new_data = [['6601206','Sakon',17,20],['6601207','Yaya',22,20]]
new_df = pd.DataFrame(new_data, columns=column_name)
new_df.head()
# Out:
#         ID   Name  Midterm  Final
# 0  6601206  Sakon       17     20
# 1  6601207   Yaya       22     20

# %% [markdown]
# ## ignore_index=True จะเรียงลำดับให้

# %%
df2 = pd.concat([df, new_df], ignore_index=True)
df2
# Out:
#          ID     Name  Midterm  Final
# 0  66011201    Rapee       25     22
# 1  66011202  Sppkjai       23     24
# 2  66011203   Rakdee       19     25
# 3  66011204     Chan       21     19
# 4  66011205     Krit       20     18
# 5   6601206    Sakon       17     20
# 6   6601207     Yaya       22     20

# %%
df3 = df2.drop(columns=['Final'])
df3.head(2)
# Out:
#          ID     Name  Midterm
# 0  66011201    Rapee       25
# 1  66011202  Sppkjai       23

# %% [markdown]
# ## สามารถ Query ได้เหมือน database เลย

# %%
df4 = df2.query('Midterm < 20')
df4
# Out:
#          ID    Name  Midterm  Final
# 2  66011203  Rakdee       19     25
# 5   6601206   Sakon       17     20

# %%
df5 = df2[df2.Midterm > 20]
df5
# Out:
#          ID     Name  Midterm  Final
# 0  66011201    Rapee       25     22
# 1  66011202  Sppkjai       23     24
# 3  66011204     Chan       21     19
# 6   6601207     Yaya       22     20
